# %% [markdown]
# ---
# title: "Sample Blog 1"
# author: "Aayush Agrawal"
# date: "2023-09-12"
# categories: ["Plotting", "Machine learning"]
# format:
#   html:
#     code-fold: true
# ---

# %% [markdown]
# ## Colors
#
# - Red
# - Blue
# - Green

# %% [markdown]
# # Equations

# %% [markdown]
# $E = mc^{2}$

# %% [markdown]
# ## Cross Referencing

# %% [markdown]
# ### Overview
# See @fig-sample in @sec-plot for a demonstration of a simple plot.
#
# See @eq-stddev to better understand standard deviation.

# %% [markdown]
# ### PLOT {#sec-plot}

# %%
#| label: fig-sample
#| fig-cap: Simple Plot
import matplotlib.pyplot as plt
plt.plot([1,23,3,4])
plt.show()

# %%
#| label: fig-sample2
#| fig-cap: Simple Plot 2
#| code-fold: false
import matplotlib.pyplot as plt
plt.plot([1,23,3,4])
plt.show()

# %% [markdown]
# ### Equation {#sec-equation}
#
# $$
# s = \sqrt{\frac{1}{N-1} \sum_{i=1}^N (x_i - \overline{x})^2}
# $$ {#eq-stddev}

# %% [markdown]
# ## Callouts

# %% [markdown]
# ::: {.callout-important collapse=true}
# Note that this is a callout. There are five types of callouts -
# `note`, `tip`, `warning`, `caution` and `important`.
# :::
